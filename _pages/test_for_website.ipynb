# %% [markdown]
# ## Test what this does

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [0,1,2,3,4]
y = [3,4,5,6,7]
z = ['a','b','c','d','e']
df = pd.DataFrame(x,y)

# %%
plt.plot(x,y)
